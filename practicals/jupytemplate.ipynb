# %% [markdown]
# <img src="media/Banner_waterlevel+esalogo.svg" width="100%" alt="Banner for EO AFRICA course" />
#
#
# *R. Rietbroek, May 2026*

# %% [markdown]
# # Jupyter Practical on ...
#
# ## What will you learn?
